# %% [markdown]
# ### Topic 8 DQ 1
#
#
# After reading the assigned articles and textbook chapters, provide an example of a dataset you would like to explore using exploratory data analysis techniques. Discuss the potential research questions or hypotheses that could be addressed through this analysis, as well as the types of visualizations and statistical techniques that might be used to explore the data. Finally, provide a brief overview of how you would approach analyzing the data in Python.
#
# Prepare your answer as follows:
#
#    - Provide a professionally written answer, anchored in scholarly work.
#    - Create a diagram, table, or other visual prop to help explain your answer and include 1–2 sentences describing the visual.
#    - Include a Jupyter notebook with the relevant Python code you created.
#    - Record a short 2- to 3-minute long video (using tools like Zoom or Loom) in which you explain your answer and code. Use an online video platform such as Loom, YouTube, or Vimeo to upload your completed video. Include the link to the video in your answer.

# %%
#Import libreries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read the data set
df = pd.read_csv("output.csv")
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
# Summary statistics
print(df.describe())
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.103478  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.159990  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
# Scatter plot: House size vs. Selling price
plt.figure(figsize=(10, 6))
sns.scatterplot(x='sqft_living', y='price', data=df)
plt.title('House Size vs. Selling Price')
plt.xlabel('House Size (sqft)')
plt.ylabel('Selling Price ($)')
plt.show()

# %%
# Box plot: Selling price by number of bedrooms
plt.figure(figsize=(10, 6))
sns.boxplot(x='bedrooms', y='price', data=df)
plt.title('Selling Price by Number of Bedrooms')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Selling Price ($)')
plt.show()

# %%
# Histogram: Distribution of house prices
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], kde=True)
plt.title('Distribution of House Prices')
plt.xlabel('Selling Price ($)')
plt.ylabel('Frequency')
plt.show()
